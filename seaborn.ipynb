# %% [markdown]
# Hello，我是宁萌，我制作了[【Python】一小时带你掌握seaborn可视化](https://www.bilibili.com/video/BV1VX4y1F76x)，以下为视频示例中的代码，结合视频练习代码，效果更佳哦！欢迎多多交流呀！
#
# 联系我：B站：[宁萌Julie](https://space.bilibili.com/40990299), email:Juliecodestack@126.com。

# %% [markdown]
# ### 一、准备工作

# %%
#安装方式：pip install seaborn或conda install seaborn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
print(sns.__version__)
# Out:
# 0.11.2

# %% [markdown]
# 如果seaborn版本不是最新的，需要更新，可以在命令行界面输入:
# `pip install —upgrade seaborn`

# %%
#查看seaborn有哪些自带的数据集
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
#分类问题：企鹅种类
penguin_df=sns.load_dataset("penguins")
penguin_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
#回归问题：估计餐馆顾客给的小费
tip_df=sns.load_dataset("tips")
tip_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# skiprows : 指定需要跳过原数据集的起始行数 
# skipfooter ：指定需要跳过原数据集的末尾行数 
wt_var = pd.read_table('/home/luotao/c_elegans/RNA-seq/SRA_yy/filter/WT_snpEff_genes.txt',skiprows=1)
wt_var
# Out:
#           #GeneName        GeneId                TranscriptId         BioType  \
# 0       CELE_2L52.1   CELE_2L52.1              NM_001381281.3  protein_coding
# 1       CELE_2L52.1   CELE_2L52.1              NM_001381282.1  protein_coding
# 2       CELE_2L52.2   CELE_2L52.2                 NR_050775.1         lincRNA
# 3      CELE_2RSSE.1  CELE_2RSSE.1              NM_001306602.4  protein_coding
# 4      CELE_2RSSE.1  CELE_2RSSE.1              NM_001364067.3  protein_coding
# ...             ...           ...                         ...             ...
# 43379     KEF34_t18     KEF34_t18  unassigned_transcript_3270  protein_coding
# 43380     KEF34_t19     KEF34_t19  unassigned_transcript_3271  protein_coding
# 43381     KEF34_t20     KEF34_t20  unassigned_transcript_3272  protein_coding
# 43382     KEF34_t21     KEF34_t21  unassigned_transcript_3274  protein_coding
# 43383     KEF34_t22     KEF34_t22  unassigned_transcript_3278  protein_coding
#
#        variants_impact_HIGH  variants_impact_LOW  variants_impact_MODERATE  \
# 0                         6                    0                         0
# 1                         3                    0                         0
# 2                         0                    0                         0
# 3                         1                    0                         0
# 4                         1                    0                         0
# ...                     ...                  ...                       ...
# 43379                     0                    0                         0
# 43380                     0                    0                         0
# 43381                     0                    0                         0
# 43382                     0                    0                         0
# 43383                     0                    0                         0
#
#        variants_impact_MODIFIER  variants_effect_3_prime_UTR_truncation  \
# 0                             0                                       0
# 1                             3                                       0
# 2                             6                                       0
# 3                             0                                       0
# 4                             0                                       0
# ...                         ...                                     ...
# 43379                         2                                       0
# 43380                         2                                       0
# 43381                         2                                       0
# 43382                         2                                       0
# 43383                         2                                       0
#
#        variants_effect_3_prime_UTR_variant  ...  \
# 0                                        0  ...
# 1                                        0  ...
# 2                                        0  ...
# 3                                        0  ...
# 4                                        0  ...
# ...                                    ...  ...
# 43379                                    0  ...
# 43380                                    0  ...
# 43381                                    0  ...
# 43382                                    0  ...
# 43383                                    0  ...
#
#        variants_effect_splice_acceptor_variant  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
# ...                                        ...
# 43379                                        0
# 43380                                        0
# 43381                                        0
# 43382                                        0
# 43383                                        0
#
#        variants_effect_splice_donor_variant  \
# 0                                         5
# 1                                         2
# 2                                         0
# 3                                         1
# 4                                         1
# ...                                     ...
# 43379                                     0
# 43380                                     0
# 43381                                     0
# 43382                                     0
# 43383                                     0
#
#        variants_effect_splice_region_variant  variants_effect_start_lost  \
# 0                                          2                           0
# 1                                          0                           0
# 2                                          0                           0
# 3                                          1                           0
# 4                                          1                           0
# ...                                      ...                         ...
# 43379                                      0                           0
# 43380                                      0                           0
# 43381                                      0                           0
# 43382                                      0                           0
# 43383                                      0                           0
#
#        variants_effect_stop_gained  variants_effect_stop_lost  \
# 0                                0                          0
# 1                                0                          0
# 2                                0                          0
# 3                                1                          0
# 4                                1                          0
# ...                            ...                        ...
# 43379                            0                          0
# 43380                            0                          0
# 43381                            0                          0
# 43382                            0                          0
# 43383                            0                          0
#
#        variants_effect_stop_retained_variant  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
# ...                                      ...
# 43379                                      0
# 43380                                      0
# 43381                                      0
# 43382                                      0
# 43383                                      0
#
#        variants_effect_synonymous_variant  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ...                                   ...
# 43379                                   0
# 43380                                   0
# 43381                                   0
# 43382                                   0
# 43383                                   0
#
#        variants_effect_transcript_ablation  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# ...                                    ...
# 43379                                    0
# 43380                                    0
# 43381                                    0
# 43382                                    0
# 43383                                    0
#
#        variants_effect_upstream_gene_variant
# 0                                          0
# 1                                          3
# 2                                          6
# 3                                          0
# 4                                          0
# ...                                      ...
# 43379                                      1
# 43380                                      1
# 43381                                      1
# 43382                                      1
# 43383                                      2
#
# [43384 rows x 35 columns]

# %% [markdown]
# ### 二、变量分布
# 我们拿到一个数据，首先要查看数值变量的分布，比如:
# - 变量取值范围，是否有异常值(outliers)？
# - 变量分布是否近似正态分布？如果不是，那么是否有偏移? 是否有双峰分布（bimodality）?
# - 如果依据类别变量对数据集进行划分，各子集上变量的分布是否有很大差异？
#
# 这些都是我们要考虑的问题。

# %% [markdown]
# #### 2.1 sns.boxplot()：查看数值变量的取值范围，是否有异常值

# %%
sns.boxplot(data=wt_var)
# Out:
# <AxesSubplot:>

# %%
sns.catplot(data=wt_var,x="variants_impact_HIGH",kind="box")

# %%
sns.boxplot(data=tip_df,x="total_bill")
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %% [markdown]
# #### 2.2 sns.displot():查看变量的分布

# %% [markdown]
# ##### 直方图

# %%
#默认为直方图
sns.displot(data=wt_var,x="variants_impact_HIGH",bins=50)

# %%
sns.histplot(wt_var,x='BioType')
# Out:
# <AxesSubplot:xlabel='BioType', ylabel='Count'>

# %%
#改变分桶数
sns.displot(data=penguin_df,x="bill_length_mm",bins=50)

# %%
sns.displot(data=penguin_df,x="bill_length_mm",bins=5)

# %%
#类别变量
sns.displot(data=wt_var,x='BioType',shrink=0.9)

# %%
sns.countplot(data=wt_var,x="BioType")
# Out:
# <AxesSubplot:xlabel='BioType', ylabel='count'>

# %% [markdown]
# ##### kde

# %%
#kde
sns.displot(x="bill_length_mm",data=penguin_df,kind="kde")

# %%
sns.displot(x="bill_length_mm",data=penguin_df,kind="kde",rug=True)

# %%
sns.kdeplot(x="bill_length_mm",data=penguin_df)
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Density'>

# %%
print(np.min(penguin_df["bill_length_mm"]))
print(np.max(penguin_df["bill_length_mm"]))
# Out:
# 32.1
# 59.6

# %%
sns.displot(x="bill_length_mm",data=penguin_df,kind="kde",cut=0)

# %%
sns.displot(x="bill_length_mm",data=penguin_df,kde=True)

# %% [markdown]
# 分析双峰分布：

# %%
sns.displot(x="variants_impact_HIGH",data=wt_var,kind="kde",hue='BioType')
# Out:
# /home/luotao/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# 分布有偏移的情况：

# %%
sns.displot(data=wt_var,x="variants_impact_HIGH")
sns.displot(data=wt_var,x="variants_impact_HIGH",log_scale=True)
# Out:
# /home/luotao/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [100], in <cell line: 2>()
#       1 sns.displot(data=wt_var,x="variants_impact_HIGH")
# ----> 2 sns.displot(data=wt_var,x="variants_impact_HIGH",log_scale=True)
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2274, in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2271 if p.univariate:
#    2273     _assign_default_kwargs(hist_kws, p.plot_univariate_histogram, histplot)
# -> 2274     p.plot_univariate_histogram(**hist_kws)
#    2276 else:
#    2278     _assign_default_kwargs(hist_kws, p.plot_bivariate_histogram, histplot)
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:441, in _DistributionPlotter.plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     438     weights = None
#     440 # Do the histogram computation
# --> 441 heights, edges = estimator(observations, weights=weights)
#     443 # Rescale the smoothed curve to match the histogram
#     444 if kde and key in densities:
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/_statistics.py:386, in Histogram.__call__(self, x1, x2, weights)
#     384 """Count the occurrences in each bin, maybe normalize."""
#     385 if x2 is None:
# --> 386     return self._eval_univariate(x1, weights)
#     387 else:
#     388     return self._eval_bivariate(x1, x2, weights)
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/_statistics.py:361, in Histogram._eval_univariate(self, x, weights)
#     359 bin_kws = self.bin_kws
#     360 if bin_kws is None:
# --> 361     bin_kws = self.define_bin_params(x, weights=weights, cache=False)
#     363 density = self.stat == "density"
#     364 hist, bin_edges = np.histogram(
#     365     x, **bin_kws, weights=weights, density=density,
#     366 )
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/_statistics.py:269, in Histogram.define_bin_params(self, x1, x2, weights, cache)
#     266 """Given data, return numpy.histogram parameters to define bins."""
#     267 if x2 is None:
# --> 269     bin_edges = self._define_bin_edges(
#     270         x1, weights, self.bins, self.binwidth, self.binrange, self.discrete,
#     271     )
#     273     if isinstance(self.bins, (str, Number)):
#     274         n_bins = len(bin_edges) - 1
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/_statistics.py:260, in Histogram._define_bin_edges(self, x, weights, bins, binwidth, binrange, discrete)
#     258     bin_edges = np.arange(start, stop + step, step)
#     259 else:
# --> 260     bin_edges = np.histogram_bin_edges(
#     261         x, bins, binrange, weights,
#     262     )
#     263 return bin_edges
#
# File <__array_function__ internals>:5, in histogram_bin_edges(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/numpy/lib/histograms.py:669, in histogram_bin_edges(a, bins, range, weights)
#     472 r"""
#     473 Function to calculate only the edges of the bins used by the `histogram`
#     474 function.
#    (...)
#     666
#     667 """
#     668 a, weights = _ravel_and_check_weights(a, weights)
# --> 669 bin_edges, _ = _get_bin_edges(a, bins, range, weights)
#     670 return bin_edges
#
# File ~/anaconda3/lib/python3.9/site-packages/numpy/lib/histograms.py:396, in _get_bin_edges(a, bins, range, weights)
#     392 if weights is not None:
#     393     raise TypeError("Automated estimation of the number of "
#     394                     "bins is not supported for weighted data")
# --> 396 first_edge, last_edge = _get_outer_edges(a, range)
#     398 # truncate the range if needed
#     399 if range is not None:
#
# File ~/anaconda3/lib/python3.9/site-packages/numpy/lib/histograms.py:323, in _get_outer_edges(a, range)
#     321     first_edge, last_edge = a.min(), a.max()
#     322     if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# --> 323         raise ValueError(
#     324             "autodetected range of [{}, {}] is not finite".format(first_edge, last_edge))
#     326 # expand empty range to avoid divide by zero
#     327 if first_edge == last_edge:
#
# ValueError: autodetected range of [-inf, 1.6720978579357175] is not finite

# %% [markdown]
# 利用kde曲线比较训练集和测试集变量分布是否一致：

# %%
from sklearn.model_selection import train_test_split
train_df,test_df=train_test_split(wt_var,test_size=0.3,random_state=42)
#sns.kdeplot(data=train_df,x="depth",marker="o")
sns.displot(data=train_df,x="variants_impact_HIGH",kind="kde",linewidth=5.0,color="r")
sns.kdeplot(data=test_df,x="variants_impact_HIGH",color="g")
# Out:
# <AxesSubplot:xlabel='variants_impact_HIGH', ylabel='Density'>

# %% [markdown]
# ##### ecdf  经验累积分布函数

# %%
sns.displot(wt_var,x="variants_impact_HIGH",kind="ecdf")

# %% [markdown]
# ##### FacetGrid特性

# %%
sns.displot(data=penguin_df,x="bill_length_mm",row="sex",col="island",hue="species",kind="kde")

# %%
tip_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### 三、（数值）变量的关系分析

# %% [markdown]
# #### 3.1 sns.relplot():绘制散点图

# %%
sns.relplot(data=tip_df,x="total_bill",y="tip",hue='time',style='time',markers=['o','^'])

# %%
sns.relplot(data=tip_df,x="total_bill",y="tip",hue="time",style="time",markers=["o","^"])

# %%
sns.relplot(data=tip_df,x="total_bill",y="tip",hue="size",size="size")

# %% [markdown]
# FacetGrid特性：

# %%
sns.relplot(data=tip_df,x="total_bill",y="tip",col="day",col_wrap=2,hue="smoker")

# %% [markdown]
# lineplot

# %%
sns.relplot(data=tip_df,x="total_bill",y="tip",kind="line")

# %%
stock_df=pd.DataFrame(dict(time=np.arange(500),price=np.random.randn(500).cumsum()+np.ones(500)*50))
sns.relplot(data=stock_df,x="time",y="price",kind="line")

# %% [markdown]
# #### 3.2 sns.lmplot()：分析两个数值变量的线性关系

# %%
sns.lmplot(data=tip_df,x="total_bill",y="tip")

# %%
sns.regplot(data=tip_df,x="total_bill",y="tip")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.residplot(data=tip_df,x="total_bill",y="tip")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(data=tip_df,x="total_bill",y="tip",hue="time")

# %% [markdown]
# FacetGrid特性：

# %%
sns.lmplot(data=tip_df,x="total_bill",y="tip",row="smoker",col="time",hue="time")

# %% [markdown]
# #### 3.3 sns.displot()：绘制两个变量的联合分布

# %%
sns.displot(data=penguin_df,x="bill_length_mm",y="bill_depth_mm",kind="kde",rug=True,levels=10,thresh=0.2)

# %%
sns.displot(data=penguin_df,x="bill_length_mm",y="bill_depth_mm",kind="kde",thresh=0.2,levels=5)

# %%
#log_scale
sns.displot(data=dia_df,x="price",y="clarity",log_scale=[True,False])

# %%
#两个类别变量
sns.displot(data=penguin_df,x="island",y="species")

# %% [markdown]
# #### 3.4 sns.jointplot()：绘制两个变量的联合分布和各自分布

# %%
#kind : { "scatter" | "kde" | "hist" | "hex" | "reg" | "resid" }
sns.jointplot(data=tip_df,x="total_bill",y="tip")

# %%
sns.jointplot(data=tip_df,x="total_bill",y="tip",hue="sex")

# %%
sns.jointplot(data=penguin_df,x="island",y="species",kind="hist")

# %% [markdown]
# jointplot的升级版：JointGrid，可通过g.plot()自定义函数

# %%
g=sns.JointGrid(data=tip_df,x="total_bill",y="tip")
g.plot(sns.histplot,sns.boxplot) # 中间直方图，两边箱式图

# %%
g=sns.JointGrid(data=tip_df,x="total_bill",y="tip")
g.plot_joint(sns.kdeplot)
g.plot_marginals(sns.histplot,kde=True)

# %% [markdown]
# #### 3.5 sns.pairplot()：成对绘制所有数值变量的联合分布

# %%
#kind : {'scatter', 'kde', 'hist', 'reg'}
sns.pairplot(data=tip_df)

# %%
#加载car_crashes数据集
car_df=sns.load_dataset("car_crashes")
car_df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# 12   15.3     5.508    4.437          13.005       14.994       641.96
# 13   12.8     4.608    4.352          12.032       12.288       803.11
# 14   14.5     3.625    4.205          13.775       13.775       710.46
# 15   15.7     2.669    3.925          15.229       13.659       649.06
# 16   17.8     4.806    4.272          13.706       15.130       780.45
# 17   21.4     4.066    4.922          16.692       16.264       872.51
# 18   20.5     7.175    6.765          14.965       20.090      1281.55
# 19   15.1     5.738    4.530          13.137       12.684       661.88
# 20   12.5     4.250    4.000           8.875       12.375      1048.78
# 21    8.2     1.886    2.870           7.134        6.560      1011.14
# 22   14.1     3.384    3.948          13.395       10.857      1110.61
# 23    9.6     2.208    2.784           8.448        8.448       777.18
# 24   17.6     2.640    5.456           1.760       17.600       896.07
# 25   16.1     6.923    5.474          14.812       13.524       790.32
# 26   21.4     8.346    9.416          17.976       18.190       816.21
# 27   14.9     1.937    5.215          13.857       13.410       732.28
# 28   14.7     5.439    4.704          13.965       14.553      1029.87
# 29   11.6     4.060    3.480          10.092        9.628       746.54
# 30   11.2     1.792    3.136           9.632        8.736      1301.52
# 31   18.4     3.496    4.968          12.328       18.032       869.85
# 32   12.3     3.936    3.567          10.824        9.840      1234.31
# 33   16.8     6.552    5.208          15.792       13.608       708.24
# 34   23.9     5.497   10.038          23.661       20.554       688.75
# 35   14.1     3.948    4.794          13.959       11.562       697.73
# 36   19.9     6.368    5.771          18.308       18.706       881.51
# 37   12.8     4.224    3.328           8.576       11.520       804.71
# 38   18.2     9.100    5.642          17.472       16.016       905.99
# 39   11.1     3.774    4.218          10.212        8.769      1148.99
# 40   23.9     9.082    9.799          22.944       19.359       858.97
# 41   19.4     6.014    6.402          19.012       16.684       669.31
# 42   19.5     4.095    5.655          15.990       15.795       767.91
# 43   19.4     7.760    7.372          17.654       16.878      1004.75
# 44   11.3     4.859    1.808           9.944       10.848       809.38
# 45   13.6     4.080    4.080          13.056       12.920       716.20
# 46   12.7     2.413    3.429          11.049       11.176       768.95
# 47   10.6     4.452    3.498           8.692        9.116       890.03
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 0       145.08     AL
# 1       133.93     AK
# 2       110.35     AZ
# 3       142.39     AR
# 4       165.63     CA
# 5       139.91     CO
# 6       167.02     CT
# 7       151.48     DE
# 8       136.05     DC
# 9       144.18     FL
# 10      142.80     GA
# 11      120.92     HI
# 12       82.75     ID
# 13      139.15     IL
# 14      108.92     IN
# 15      114.47     IA
# 16      133.80     KS
# 17      137.13     KY
# 18      194.78     LA
# 19       96.57     ME
# 20      192.70     MD
# 21      135.63     MA
# 22      152.26     MI
# 23      133.35     MN
# 24      155.77     MS
# 25      144.45     MO
# 26       85.15     MT
# 27      114.82     NE
# 28      138.71     NV
# 29      120.21     NH
# 30      159.85     NJ
# 31      120.75     NM
# 32      150.01     NY
# 33      127.82     NC
# 34      109.72     ND
# 35      133.52     OH
# 36      178.86     OK
# 37      104.61     OR
# 38      153.86     PA
# 39      148.58     RI
# 40      116.29     SC
# 41       96.87     SD
# 42      155.57     TN
# 43      156.83     TX
# 44      109.48     UT
# 45      109.61     VT
# 46      153.72     VA
# 47      111.62     WA
# 48      152.56     WV
# 49      106.62     WI
# 50      122.04     WY

# %%
sns.pairplot(data=car_df,kind="reg")

# %%
sns.pairplot(data=car_df,x_vars=["speeding","alcohol"],y_vars=["total"])

# %% [markdown]
# pairplot的升级版：PairGrid，可通过g.map()自定义绘制函数

# %%
g=sns.PairGrid(data=car_df,x_vars=["total","speeding","alcohol"],y_vars=["total","speeding","alcohol"])
g.map_upper(sns.scatterplot)
g.map_diag(sns.histplot,kde=True)
g.map_lower(sns.regplot)

# %% [markdown]
# #### 3.6 data.corr()+sns.heatmap()：成对绘制所有数值变量的相关系数

# %%
car_cor=car_df.corr()
car_cor
# Out:
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# speeding          -0.077675   -0.065928
# alcohol           -0.170612   -0.112547
# not_distracted    -0.174856   -0.075970
# no_previous       -0.156895   -0.006359
# ins_premium        1.000000    0.623116
# ins_losses         0.623116    1.000000

# %%
sns.heatmap(car_cor,cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(car_cor,cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(car_cor,cmap="coolwarm",annot=True,fmt=".2f",linewidth=0.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 四、类别变量的分析

# %% [markdown]
# #### 4.1 类别变量的分布：sns.countplot()，类似sns.histplot()

# %%
sns.catplot(data=tip_df,x="time",kind="count")

# %% [markdown]
# #### 4.2 类别变量与数值变量的关系：
# ##### （1）不同类别中数值变量的均值/中值估计：barplot,pointplot

# %%
sns.catplot(data=penguin_df,x="species",y="bill_length_mm",kind="bar")
sns.catplot(data=penguin_df,x="species",y="bill_length_mm",kind="bar",estimator=np.median)

# %%
sns.catplot(data=penguin_df,x="species",y="bill_length_mm",kind="point",hue="island")
sns.catplot(data=penguin_df,x="species",y="bill_length_mm",kind="point")

# %% [markdown]
# sns.catplot()的FacetGrid特性：

# %%
sns.catplot(data=tip_df,x="time",y="tip",kind="bar",col="size",col_wrap=3)

# %% [markdown]
# ##### （2）不同类别中数值变量的取值范围：boxplot,boxenplot

# %%
sns.catplot(data=penguin_df,x="species",y="bill_length_mm",kind="box")

# %% [markdown]
# boxenplot:适合大数据集

# %%
sns.catplot(data=dia_df,x="clarity",y="price",kind="box")
sns.catplot(data=dia_df,x="clarity",y="price",kind="boxen")

# %% [markdown]
# ##### （3）不同类别中数值变量的分布图：stripplot,swarmplot,violinplot

# %%
sns.catplot(data=penguin_df,x="species",y="bill_length_mm",kind="strip")

# %%
sns.catplot(data=penguin_df,x="species",y="bill_length_mm",kind="strip",jitter=False)

# %%
sns.catplot(data=penguin_df,x="species",y="bill_length_mm",kind="strip",jitter=0.3)

# %%
sns.catplot(data=penguin_df,x="species",y="bill_length_mm",kind="swarm")

# %%
sns.catplot(data=penguin_df,x="species",y="bill_length_mm",kind="violin")

# %%
sns.catplot(data=penguin_df,x="species",y="bill_length_mm",kind="violin")
sns.swarmplot(data=penguin_df,x="species",y="bill_length_mm",color="w",size=3)
# Out:
# <AxesSubplot:xlabel='species', ylabel='bill_length_mm'>

# %%
sns.catplot(data=penguin_df,x="species",y="bill_length_mm",hue="sex",kind="violin",split=True)

# %% [markdown]
# ### 五、FacetGrid,PairGrid 中自定义绘制函数

# %% [markdown]
# FacetGrid

# %%
g=sns.FacetGrid(data=tip_df,row="time",col="smoker")

# %%
g=sns.FacetGrid(data=tip_df,row="smoker",col="time")
g.map(sns.kdeplot,"tip")

# %%
g=sns.FacetGrid(data=tip_df,row="time",col="smoker")
#错误：g.map(sns.scatterplot,data=tip_df,x="total_bill",y="tip")
g.map(sns.scatterplot,"total_bill","tip")

# %% [markdown]
# PairGrid

# %%
g=sns.PairGrid(data=penguin_df)

# %%
g=sns.PairGrid(data=penguin_df,hue="species")
g.map(sns.scatterplot)

# %%
g=sns.PairGrid(data=penguin_df,hue="species")
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.scatterplot)

# %%
g=sns.PairGrid(data=penguin_df)
g.map_diag(sns.histplot)
g.map_upper(sns.kdeplot)
g.map_lower(sns.scatterplot)
